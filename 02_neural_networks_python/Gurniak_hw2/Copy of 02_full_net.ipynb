# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !git clone https://github.com/argonne-lcf/ai-science-training-series.git
# %cd ai-science-training-series/02_neural_networks_python/
# Out:
# Cloning into 'ai-science-training-series'...
# remote: Enumerating objects: 2282, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 2282 (delta 58), reused 89 (delta 52), pack-reused 2184
# Receiving objects: 100% (2282/2282), 222.23 MiB | 32.32 MiB/s, done.
# Resolving deltas: 100% (1129/1129), done.
# Checking out files: 100% (272/272), done.
# /content/ai-science-training-series/02_neural_networks_python

# %%
# %matplotlib inline

import tensorflow as tf

import numpy
import matplotlib.pyplot as plt

# %%
# repeating the data prep from the previous notebook
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = x_train.astype(numpy.float32)
x_test  = x_test.astype(numpy.float32)

x_train /= 255.
x_test  /= 255.

print(x_train.shape)
x_train = x_train.reshape(x_train.shape[0], numpy.prod(x_train[0,:,:].shape))
x_test = x_test.reshape(x_test.shape[0], numpy.prod(x_test[0,:,:].shape))

print(x_train.shape)
y_train = y_train.astype(numpy.int32)
y_test  = y_test.astype(numpy.int32)

print()
print('MNIST data loaded: train:',len(x_train),'test:',len(x_test))
print('X_train:', x_train.shape)
print('y_train:', y_train.shape)

# one-hot encoding:
nb_classes = 10
y_train_onehot = tf.keras.utils.to_categorical(y_train, nb_classes)
y_test_onehot = tf.keras.utils.to_categorical(y_test, nb_classes)
# Out:
# (60000, 28, 28)
# (60000, 784)
#
# MNIST data loaded: train: 60000 test: 10000
# X_train: (60000, 784)
# y_train: (60000,)

# %%
# Here we import an implementation of a two-layer neural network 
# this code is based on pieces of the first assignment from Stanford's CSE231n course, 
# hosted at https://github.com/cs231n/cs231n.github.io with the MIT license
from fc_net import TwoLayerNet

# %%
num_features = x_train.shape[1] # this is the number of pixels
# The weights are initialized from a normal distribution with standard deviation weight_scale
model = TwoLayerNet(input_dim=num_features, hidden_dim=300, num_classes=nb_classes, weight_scale=.01)

# %%
# here you can take a look if you want at the initial loss from an untrained network
loss, gradients = model.loss(x_train, y_train_onehot)

# %%
# a simple implementation of stochastic gradient descent
def sgd(model, gradients, learning_rate):
    for p, w in model.params.items():
        dw = gradients[p]
        new_weights = w - learning_rate * dw
        model.params[p] = new_weights
    return model

# %%
# one training step
def learn(model, x_train, y_train_onehot, learning_rate):
    loss, gradients = model.loss(x_train, y_train_onehot)
    model = sgd(model, gradients, learning_rate)
    return loss, model

# %%
def accuracy(model, x, true_values):
    scores = model.loss(x)
    predictions = numpy.argmax(scores, axis=1)
    N = predictions.shape[0]
    acc = (true_values == predictions).sum() / N
    return acc

# %%
# Here's an example training loop using this two-layer model. Can you do better? 
learning_rate = 0.01  
num_examples = x_train.shape[0]
batch_size = 10000
num_batches = int(num_examples / batch_size)
num_epochs = 100
losses = numpy.zeros(num_batches*num_epochs,)
indices = numpy.arange(num_examples)

i = 0
for epoch in range(0, num_epochs):
    # in each epoch, we loop over all of the training examples
    for step in range(0, num_batches):
        # grabbing the next batch
        offset = step * batch_size
        batch_range = range(offset, offset+batch_size)
        x_train_batch = x_train[batch_range, :]
        y_train_batch = y_train_onehot[batch_range,:]
        
        # feed the next batch in to do one sgd step
        loss, model = learn(model, x_train_batch, y_train_batch, learning_rate)
        losses[i] = loss
        i += 1

    acc = accuracy(model, x_train, y_train)
    print("epoch %d, loss %.5f, accuracy %.2f" % (epoch, loss, acc))
    
    # reshuffle the data so that we get a new set of batches
    numpy.random.shuffle(indices)
    x_train = x_train[indices,:]
    y_train = y_train[indices] # keep this shuffled the same way for use in accuracy calculation
    y_train_onehot = y_train_onehot[indices,:]
plt.plot(losses)
# Out:
# epoch 0, loss 2.28264, accuracy 0.39
# epoch 1, loss 2.28059, accuracy 0.40
# epoch 2, loss 2.27876, accuracy 0.41
# epoch 3, loss 2.27648, accuracy 0.42
# epoch 4, loss 2.27402, accuracy 0.43
# epoch 5, loss 2.27248, accuracy 0.44
# epoch 6, loss 2.26984, accuracy 0.45
# epoch 7, loss 2.26774, accuracy 0.45
# epoch 8, loss 2.26470, accuracy 0.46
# epoch 9, loss 2.26258, accuracy 0.46
# epoch 10, loss 2.25880, accuracy 0.46
# epoch 11, loss 2.25665, accuracy 0.47
# epoch 12, loss 2.25308, accuracy 0.47
# epoch 13, loss 2.25084, accuracy 0.47
# epoch 14, loss 2.24766, accuracy 0.48
# epoch 15, loss 2.24365, accuracy 0.48
# epoch 16, loss 2.24062, accuracy 0.48
# epoch 17, loss 2.23764, accuracy 0.49
# epoch 18, loss 2.23178, accuracy 0.49
# epoch 19, loss 2.22793, accuracy 0.49
# epoch 20, loss 2.22452, accuracy 0.50
# epoch 21, loss 2.22181, accuracy 0.50
# epoch 22, loss 2.21572, accuracy 0.50
# epoch 23, loss 2.21201, accuracy 0.50
# epoch 24, loss 2.20663, accuracy 0.51
# epoch 25, loss 2.20177, accuracy 0.51
# epoch 26, loss 2.19664, accuracy 0.51
# epoch 27, loss 2.19013, accuracy 0.52
# epoch 28, loss 2.18288, accuracy 0.52
# epoch 29, loss 2.17788, accuracy 0.52
# epoch 30, loss 2.17114, accuracy 0.53
# epoch 31, loss 2.16789, accuracy 0.53
# epoch 32, loss 2.15989, accuracy 0.54
# epoch 33, loss 2.15550, accuracy 0.54
# epoch 34, loss 2.14512, accuracy 0.55
# epoch 35, loss 2.13584, accuracy 0.55
# epoch 36, loss 2.13158, accuracy 0.55
# epoch 37, loss 2.12077, accuracy 0.56
# epoch 38, loss 2.11353, accuracy 0.56
# epoch 39, loss 2.10627, accuracy 0.57
# epoch 40, loss 2.09706, accuracy 0.57
# epoch 41, loss 2.08616, accuracy 0.58
# epoch 42, loss 2.07227, accuracy 0.58
# epoch 43, loss 2.06706, accuracy 0.59
# epoch 44, loss 2.05771, accuracy 0.59
# epoch 45, loss 2.04358, accuracy 0.60
# epoch 46, loss 2.03726, accuracy 0.60
# epoch 47, loss 2.02769, accuracy 0.61
# epoch 48, loss 2.01628, accuracy 0.61
# epoch 49, loss 2.00462, accuracy 0.62
# epoch 50, loss 1.99193, accuracy 0.62
# epoch 51, loss 1.97898, accuracy 0.63
# epoch 52, loss 1.96575, accuracy 0.63
# epoch 53, loss 1.95742, accuracy 0.64
# epoch 54, loss 1.94140, accuracy 0.64
# epoch 55, loss 1.92803, accuracy 0.65
# epoch 56, loss 1.91462, accuracy 0.65
# epoch 57, loss 1.90555, accuracy 0.65
# epoch 58, loss 1.89163, accuracy 0.66
# epoch 59, loss 1.87310, accuracy 0.66
# epoch 60, loss 1.86283, accuracy 0.66
# epoch 61, loss 1.84388, accuracy 0.67
# epoch 62, loss 1.83499, accuracy 0.67
# epoch 63, loss 1.81766, accuracy 0.67
# epoch 64, loss 1.80462, accuracy 0.68
# epoch 65, loss 1.78088, accuracy 0.68
# epoch 66, loss 1.76633, accuracy 0.68
# epoch 67, loss 1.75547, accuracy 0.68
# epoch 68, loss 1.73497, accuracy 0.69
# epoch 69, loss 1.72340, accuracy 0.69
# epoch 70, loss 1.70713, accuracy 0.69
# epoch 71, loss 1.69810, accuracy 0.69
# epoch 72, loss 1.67606, accuracy 0.70
# epoch 73, loss 1.66262, accuracy 0.70
# epoch 74, loss 1.64161, accuracy 0.70
# epoch 75, loss 1.62391, accuracy 0.70
# epoch 76, loss 1.60856, accuracy 0.70
# epoch 77, loss 1.58824, accuracy 0.70
# epoch 78, loss 1.58079, accuracy 0.71
# epoch 79, loss 1.56715, accuracy 0.71
# epoch 80, loss 1.53955, accuracy 0.71
# epoch 81, loss 1.52318, accuracy 0.71
# epoch 82, loss 1.50636, accuracy 0.71
# epoch 83, loss 1.49492, accuracy 0.71
# epoch 84, loss 1.47546, accuracy 0.72
# epoch 85, loss 1.46184, accuracy 0.72
# epoch 86, loss 1.44603, accuracy 0.72
# epoch 87, loss 1.43569, accuracy 0.72
# epoch 88, loss 1.41108, accuracy 0.72
# epoch 89, loss 1.40080, accuracy 0.72
# epoch 90, loss 1.38939, accuracy 0.73
# epoch 91, loss 1.36520, accuracy 0.73
# epoch 92, loss 1.36183, accuracy 0.73
# epoch 93, loss 1.33632, accuracy 0.73
# epoch 94, loss 1.32827, accuracy 0.73
# epoch 95, loss 1.31236, accuracy 0.74
# epoch 96, loss 1.30591, accuracy 0.74
# epoch 97, loss 1.27663, accuracy 0.74
# epoch 98, loss 1.27690, accuracy 0.74
# epoch 99, loss 1.26474, accuracy 0.75

# %%
accuracy(model, x_train, y_train)
# Out:
# 0.7456333333333334

# %% [markdown]
# # Homework: improve the accuracy of this model.

# %% [markdown]
# Update this notebook so that the accuracy is improved. How high can you get it? You could change things directly in the notebook, such as increasing the number of epochs, changing the learning weight, changing the width of the hidden layer, etc. If you're more ambitious, you could also try changing the model definition itself by checking out the associated Python files. For example, you could add more layers to the network. The current notebook has a training accuracy of about 43%, but will vary with randomness.

# %%
# Here's an example training loop using this two-layer model. Can you do better? 
learning_rate = 0.02  
num_examples = x_train.shape[0]
batch_size = 10000
num_batches = int(num_examples / batch_size)
num_epochs = 100
losses = numpy.zeros(num_batches*num_epochs,)
indices = numpy.arange(num_examples)

i = 0
for epoch in range(0, num_epochs):
    # in each epoch, we loop over all of the training examples
    for step in range(0, num_batches):
        # grabbing the next batch
        offset = step * batch_size
        batch_range = range(offset, offset+batch_size)
        x_train_batch = x_train[batch_range, :]
        y_train_batch = y_train_onehot[batch_range,:]
        
        # feed the next batch in to do one sgd step
        loss, model = learn(model, x_train_batch, y_train_batch, learning_rate)
        losses[i] = loss
        i += 1

    acc = accuracy(model, x_train, y_train)
    print("epoch %d, loss %.5f, accuracy %.2f" % (epoch, loss, acc))
    
    # reshuffle the data so that we get a new set of batches
    numpy.random.shuffle(indices)
    x_train = x_train[indices,:]
    y_train = y_train[indices] # keep this shuffled the same way for use in accuracy calculation
    y_train_onehot = y_train_onehot[indices,:]
plt.plot(losses)
# Out:
# epoch 0, loss 1.23695, accuracy 0.75
# epoch 1, loss 1.20999, accuracy 0.75
# epoch 2, loss 1.19130, accuracy 0.76
# epoch 3, loss 1.15906, accuracy 0.76
# epoch 4, loss 1.13543, accuracy 0.77
# epoch 5, loss 1.11572, accuracy 0.77
# epoch 6, loss 1.10233, accuracy 0.77
# epoch 7, loss 1.07527, accuracy 0.78
# epoch 8, loss 1.05823, accuracy 0.78
# epoch 9, loss 1.03767, accuracy 0.78
# epoch 10, loss 1.01455, accuracy 0.79
# epoch 11, loss 1.00123, accuracy 0.79
# epoch 12, loss 0.98274, accuracy 0.79
# epoch 13, loss 0.96946, accuracy 0.79
# epoch 14, loss 0.95697, accuracy 0.80
# epoch 15, loss 0.93696, accuracy 0.80
# epoch 16, loss 0.92914, accuracy 0.80
# epoch 17, loss 0.90950, accuracy 0.80
# epoch 18, loss 0.89803, accuracy 0.80
# epoch 19, loss 0.88902, accuracy 0.81
# epoch 20, loss 0.87672, accuracy 0.81
# epoch 21, loss 0.86108, accuracy 0.81
# epoch 22, loss 0.85688, accuracy 0.81
# epoch 23, loss 0.83632, accuracy 0.81
# epoch 24, loss 0.82309, accuracy 0.81
# epoch 25, loss 0.80810, accuracy 0.82
# epoch 26, loss 0.79929, accuracy 0.82
# epoch 27, loss 0.79960, accuracy 0.82
# epoch 28, loss 0.79125, accuracy 0.82
# epoch 29, loss 0.77107, accuracy 0.82
# epoch 30, loss 0.76260, accuracy 0.82
# epoch 31, loss 0.76081, accuracy 0.82
# epoch 32, loss 0.75047, accuracy 0.83
# epoch 33, loss 0.74780, accuracy 0.83
# epoch 34, loss 0.73024, accuracy 0.83
# epoch 35, loss 0.72178, accuracy 0.83
# epoch 36, loss 0.72256, accuracy 0.83
# epoch 37, loss 0.71661, accuracy 0.83
# epoch 38, loss 0.71277, accuracy 0.83
# epoch 39, loss 0.69604, accuracy 0.83
# epoch 40, loss 0.68942, accuracy 0.83
# epoch 41, loss 0.69105, accuracy 0.84
# epoch 42, loss 0.68917, accuracy 0.84
# epoch 43, loss 0.67275, accuracy 0.84
# epoch 44, loss 0.66652, accuracy 0.84
# epoch 45, loss 0.67316, accuracy 0.84
# epoch 46, loss 0.66412, accuracy 0.84
# epoch 47, loss 0.65369, accuracy 0.84
# epoch 48, loss 0.64244, accuracy 0.84
# epoch 49, loss 0.64096, accuracy 0.84
# epoch 50, loss 0.63605, accuracy 0.84
# epoch 51, loss 0.63358, accuracy 0.85
# epoch 52, loss 0.62399, accuracy 0.85
# epoch 53, loss 0.63317, accuracy 0.85
# epoch 54, loss 0.62333, accuracy 0.85
# epoch 55, loss 0.61167, accuracy 0.85
# epoch 56, loss 0.61163, accuracy 0.85
# epoch 57, loss 0.60934, accuracy 0.85
# epoch 58, loss 0.60311, accuracy 0.85
# epoch 59, loss 0.59286, accuracy 0.85
# epoch 60, loss 0.58679, accuracy 0.85
# epoch 61, loss 0.59999, accuracy 0.85
# epoch 62, loss 0.58732, accuracy 0.85
# epoch 63, loss 0.58462, accuracy 0.85
# epoch 64, loss 0.58053, accuracy 0.86
# epoch 65, loss 0.58205, accuracy 0.86
# epoch 66, loss 0.58854, accuracy 0.86
# epoch 67, loss 0.57369, accuracy 0.86
# epoch 68, loss 0.57225, accuracy 0.86
# epoch 69, loss 0.57362, accuracy 0.86
# epoch 70, loss 0.55952, accuracy 0.86
# epoch 71, loss 0.56332, accuracy 0.86
# epoch 72, loss 0.54866, accuracy 0.86
# epoch 73, loss 0.54999, accuracy 0.86
# epoch 74, loss 0.55205, accuracy 0.86
# epoch 75, loss 0.53494, accuracy 0.86
# epoch 76, loss 0.55037, accuracy 0.86
# epoch 77, loss 0.54988, accuracy 0.86
# epoch 78, loss 0.53366, accuracy 0.86
# epoch 79, loss 0.53239, accuracy 0.86
# epoch 80, loss 0.52436, accuracy 0.86
# epoch 81, loss 0.54133, accuracy 0.87
# epoch 82, loss 0.51793, accuracy 0.87
# epoch 83, loss 0.52344, accuracy 0.87
# epoch 84, loss 0.52861, accuracy 0.87
# epoch 85, loss 0.53171, accuracy 0.87
# epoch 86, loss 0.53768, accuracy 0.87
# epoch 87, loss 0.50546, accuracy 0.87
# epoch 88, loss 0.50267, accuracy 0.87
# epoch 89, loss 0.51627, accuracy 0.87
# epoch 90, loss 0.50640, accuracy 0.87
# epoch 91, loss 0.50602, accuracy 0.87
# epoch 92, loss 0.50792, accuracy 0.87
# epoch 93, loss 0.50065, accuracy 0.87
# epoch 94, loss 0.50930, accuracy 0.87
# epoch 95, loss 0.50285, accuracy 0.87
# epoch 96, loss 0.48836, accuracy 0.87
# epoch 97, loss 0.50712, accuracy 0.87
# epoch 98, loss 0.50030, accuracy 0.87
# epoch 99, loss 0.48898, accuracy 0.87
